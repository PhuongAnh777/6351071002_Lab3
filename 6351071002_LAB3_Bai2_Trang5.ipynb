# %% [markdown]
# # Câu a

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
# Tải bộ dữ liệu MNIST
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

print("✓ Đã tải bộ dữ liệu MNIST thành công!\n")
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# ✓ Đã tải bộ dữ liệu MNIST thành công!

# %% [markdown]
# # Câu b

# %%
print("Trần Phương Anh - 6351071002")
print("\nKích thước dữ liệu gốc:")
print("-" * 40)
print(f"  - Tập train (train_images): {train_images.shape}")
print(f"    + Số lượng ảnh: {train_images.shape[0]}")
print(f"    + Kích thước ảnh: {train_images.shape[1]}x{train_images.shape[2]} pixels")
print(f"  - Nhãn train (train_labels): {train_labels.shape}")

print(f"\n  - Tập test (test_images): {test_images.shape}")
print(f"    + Số lượng ảnh: {test_images.shape[0]}")
print(f"    + Kích thước ảnh: {test_images.shape[1]}x{test_images.shape[2]} pixels")
print(f"  - Nhãn test (test_labels): {test_labels.shape}")
# Out:
# Trần Phương Anh - 6351071002
#
# Kích thước dữ liệu gốc:
# ----------------------------------------
#   - Tập train (train_images): (60000, 28, 28)
#     + Số lượng ảnh: 60000
#     + Kích thước ảnh: 28x28 pixels
#   - Nhãn train (train_labels): (60000,)
#
#   - Tập test (test_images): (10000, 28, 28)
#     + Số lượng ảnh: 10000
#     + Kích thước ảnh: 28x28 pixels
#   - Nhãn test (test_labels): (10000,)
